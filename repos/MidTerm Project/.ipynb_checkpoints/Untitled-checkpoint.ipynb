# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from re import sub
from decimal import Decimal
from scipy import stats
import seaborn as sns

# %%
df = pd.read_csv('Data/listings.csv')

# %%
df.head(10)
# Out:
#        id                                               name  host_id  \
# 0  108061  Walk to stores/parks/downtown. Fenced yard/Pet...   320564
# 1  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 2  156805                  Private Room "Ader" at BPS Hostel   746673
# 3  156926             Mixed Dorm "Top Bunk #1" at BPS Hostel   746673
# 4  160594                                Historic Grove Park   769252
# 5  209068                                    Terrace Cottage  1029919
# 6  246315                          Asheville Dreamer's Cabin  1292070
# 7  259576           Private, peaceful, and free goat therapy  1362726
# 8  295496                  The Fern Street Apt near Biltmore  1501882
# 9  304379                         Refocus Cottage - paradise  1566145
#
#    host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0       Lisa                  NaN          28801  35.60670  -82.55563
# ...

# %%
df['price'].value_counts().sort_values(ascending=False)
# Out:
# 125     41
# 99      33
# 150     30
# 75      27
# 100     27
#         ..
# 296      1
# 800      1
# 465      1
# 1900     1
# 3200     1
# Name: price, Length: 473, dtype: int64

# %%
df.loc[df['price'] == 3200]
# Out:
#             id                                             name   host_id  \
# 2562  52828490  Monthly - Downtown West Asheville with Hot Tub!  80696321
#
#      host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 2562    Brenda                  NaN          28806  35.57604  -82.59283
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# 2562  Entire home/apt   3200              30                  0         NaN
#
#       reviews_per_month  calculated_host_listings_count  availability_365  \
# 2562                NaN                               1               176
#
#       number_of_reviews_ltm  license
# 2562                      0      NaN

# %%
df['room_type'].value_counts()
# Out:
# Entire home/apt    2150
# Private room        388
# Hotel room           17
# Shared room           8
# Name: room_type, dtype: int64

# %%
df.query("(price > 2000) and (minimum_nights ==1)")
# Out:
#            id                                        name    host_id  \
# 793  23788596  The Applewood Manor - Asheville 6 room b&b  175871539
#
#     host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 793   Stephen                  NaN          28801  35.60704  -82.56453
#
#       room_type  price  minimum_nights  number_of_reviews last_review  \
# 793  Hotel room   2214               1                  9  2021-06-20
#
#      reviews_per_month  calculated_host_listings_count  availability_365  \
# 793               0.23                               7               235
#
#      number_of_reviews_ltm  license
# 793                      2      NaN

# %%
df['host_id'].value_counts()
# Out:
# 167186184    104
# 96187307      41
# 149601167     38
# 151397468     23
# 134903005     20
#             ...
# 176828759      1
# 400858996      1
# 176072701      1
# 165107573      1
# 80696321       1
# Name: host_id, Length: 1642, dtype: int64

# %%
df.query("host_id == 167186184")
# Out:
#             id                                               name    host_id  \
# 1096  31260007  New, Contemporary South Slope Townhome with Pr...  167186184
# 1098  31267687                New luxury in the heart of downtown  167186184
# 1099  31315518  New, Luxury Condo in Downtown Asheville Condot...  167186184
# 1100  31318558  New, Luxury Condo in Downtown Asheville Condot...  167186184
# 1101  31318559  New, Luxury Condo in Downtown Asheville Condot...  167186184
# ...        ...                                                ...        ...
# 2524  52471532         South Asheville Townhome Wonderful Getaway  167186184
# 2525  52474452               Exceptional South Asheville Townhome  167186184
# 2526  52474453                  Absolutely Amazing Downtown Condo  167186184
# 2550  52668715  Wonderful newly renovated South Asheville Town...  167186184
# 2556  52718800               Comfortable South Asheville Townhome  167186184
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2563 entries, 0 to 2562
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              2563 non-null   int64
#  1   name                            2563 non-null   object
#  2   host_id                         2563 non-null   int64
#  3   host_name                       2563 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   2563 non-null   int64
#  6   latitude                        2563 non-null   float64
#  7   longitude                       2563 non-null   float64
#  8   room_type                       2563 non-null   object
#  9   price                           2563 non-null   int64
#  10  minimum_nights                  2563 non-null   int64
#  11  number_of_reviews               2563 non-null   int64
# ...

# %%
df.describe()
# Out:
#                  id       host_id  neighbourhood_group  neighbourhood  \
# count  2.563000e+03  2.563000e+03                  0.0    2563.000000
# mean   3.254194e+07  1.170267e+08                  NaN   28793.089348
# std    1.467069e+07  1.127773e+08                  NaN      29.664429
# min    1.080610e+05  6.266700e+04                  NaN   28704.000000
# 25%    2.107460e+07  2.153920e+07                  NaN   28801.000000
# 50%    3.467080e+07  8.415022e+07                  NaN   28804.000000
# 75%    4.571566e+07  1.713014e+08                  NaN   28806.000000
# max    5.282849e+07  4.256017e+08                  NaN   28806.000000
#
#           latitude    longitude        price  minimum_nights  \
# count  2563.000000  2563.000000  2563.000000     2563.000000
# mean     35.577127   -82.557929   192.059696        5.287944
# std       0.048144     0.047523   165.077998       13.786788
# min      35.423420   -82.691050    19.000000        1.000000
# ...

# %%
print(list(df))
# Out:
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'number_of_reviews_ltm', 'license']

# %%
test_df = df[df['room_type'] == 'Entire home/apt']

# %%
test_df.head()
# Out:
#        id                                               name  host_id  \
# 0  108061  Walk to stores/parks/downtown. Fenced yard/Pet...   320564
# 1  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 5  209068                                    Terrace Cottage  1029919
# 7  259576           Private, peaceful, and free goat therapy  1362726
# 8  295496                  The Fern Street Apt near Biltmore  1501882
#
#   host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0      Lisa                  NaN          28801  35.60670  -82.55563
# 1   BonPaul                  NaN          28806  35.57864  -82.59578
# 5     Kevin                  NaN          28804  35.61856  -82.55276
# 7     Julia                  NaN          28805  35.61929  -82.48114
# 8    Debbie                  NaN          28803  35.55537  -82.53539
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
reviews_df=pd.read_csv('Data/reviews.csv')

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219552 entries, 0 to 219551
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  219552 non-null  int64
#  1   date        219552 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 3.4+ MB

# %%
reviews_detailed_df=pd.read_csv('Data/reviews 2.csv')

# %%
reviews_detailed_df.head(-10)
# Out:
#         listing_id                  id        date  reviewer_id  \
# 0           108061              553741  2011-09-21       822907
# 1           108061              683278  2011-11-01       236064
# 2           108061              714889  2011-11-13      1382707
# 3           108061             1766157  2012-07-21       416731
# 4           108061             2033065  2012-08-19      1858880
# ...            ...                 ...         ...          ...
# 219537    52438122  469463743095527133  2021-10-09     90327532
# 219538    52438122  471696106127531821  2021-10-12    394424216
# 219539    52438122  473818985414901657  2021-10-15    224937377
# 219540    52438122  474614130016980241  2021-10-16    156208775
# 219541    52458524  468028752947772681  2021-10-07    146537201
#
#         reviewer_name                                           comments
# 0       Pedro & Katie  Lisa is superb hostess, she will treat you lik...
# ...

# %%
listings_detailed_df=pd.read_csv('Data/listings 2.csv')

# %%
print(list(listings_detailed_df))
# Out:
# ['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365'
# ...

# %%
keeper_columns = ['id',
                'name',
                'host_id',
                'host_name',
                'neighbourhood',
                'neighborhood_overview',
                'host_since',
                'host_location',
                'host_listings_count',
                'host_total_listings_count',
                'latitude',
                'longitude',
                'room_type',
                'price',
                'minimum_nights',
                'number_of_reviews',
                'last_review',
                'reviews_per_month',
                'calculated_host_listings_count',
                'availability_30',
                'availability_365',
                'number_of_reviews_ltm',
                 'number_of_reviews_l30d',
                 'first_review',
                 'last_review',
                 'review_scores_rating',
                 'review_scores_accuracy',
                 'review_scores_cleanliness',
                 'review_scores_location', 'review_scores_value',
                 'license',
                 'calculated_host_listings_count', 
                  'calculated_host_listings_count_entire_homes', 
                  'calculated_host_listings_count_private_rooms', 
                  'calculated_host_listings_count_shared_rooms',
                 'reviews_per_month'
                 ]

# %%
listings_detailed_df.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2563 entries, 0 to 2562
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            2563 non-null   int64
#  1   listing_url                                   2563 non-null   object
#  2   scrape_id                                     2563 non-null   int64
#  3   last_scraped                                  2563 non-null   object
#  4   name                                          2563 non-null   object
#  5   description                                   2557 non-null   object
#  6   neighborhood_overview                         2001 non-null   object
#  7   picture_url                                   2563 non-null   object
#  8   host_id                                       2563 non-null   int64
# ...

# %%
len(listings_detailed_df['price'])
# Out:
# 2563

# %%
#listings_detailed_df['price'].map(Decimal(sub(r'[^\d.]', '', listings_detailed_df['price'])))
#listings_detailed_df['price'] = pd.to_numeric(listings_detailed_df['price'].str.replace("$","").str.replace(",",""), downcast="float")

# %%
'''set variable for with type of room you are interested in:
    'Entire home/apt'    
    'Private room'        
    'Hotel room'           
    'Shared room'
    To return all room types, set value to 'All' 
'''
room_type = 'All'

# %%
def keep_pertinent_listings_data(df, by_room_type=True):
    if by_room_type:
        df= df[df['room_type'] == room_type]
    df['price'] = df['price'].str.replace("[$, ]", "").astype("float")
    df['price'] = df['price'].astype("int")
    #drop columns you don't want to keep:
    new_df = df.drop(columns=[col for col in df if col not in keeper_columns])
    #keep only those listings which are for the Entire Home as those are illegal in Asheville
    print(f"There are {new_df['id'].count()} entries for {room_type} listings, there are {new_df['license'].count()} licenses.")
    return new_df

# %%
new_listings_df = keep_pertinent_listings_data(listings_detailed_df,False)
# Out:
# There are 2563 entries for All listings, there are 0 licenses.
# /var/folders/dx/xjmpmc054qj5vlxv2c52xq1w0000gn/T/ipykernel_1580/413510433.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['price'] = df['price'].str.replace("[$, ]", "").astype("float")

# %%
new_listings_df.head()
# Out:
#        id                                               name  \
# 0  108061  Walk to stores/parks/downtown. Fenced yard/Pet...
# 1  155305                 Cottage! BonPaul + Sharky's Hostel
# 2  156805                  Private Room "Ader" at BPS Hostel
# 3  156926             Mixed Dorm "Top Bunk #1" at BPS Hostel
# 4  160594                                Historic Grove Park
#
#                                neighborhood_overview  host_id  host_name  \
# 0  I love my neighborhood! Its friendly, easy-goi...   320564       Lisa
# 1  We are within easy walk of pubs, breweries, mu...   746673    BonPaul
# 2  Easy walk to pubs, cafes, bakery, breweries, l...   746673    BonPaul
# 3                                                NaN   746673    BonPaul
# 4                                                NaN   769252  Elizabeth
#
#    host_since                               host_location  \
# 0  2010-12-16  Mills River, North Carolina, United States
# ...

# %%
new_listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2563 entries, 0 to 2562
# Data columns (total 33 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            2563 non-null   int64
#  1   name                                          2563 non-null   object
#  2   neighborhood_overview                         2001 non-null   object
#  3   host_id                                       2563 non-null   int64
#  4   host_name                                     2563 non-null   object
#  5   host_since                                    2563 non-null   object
#  6   host_location                                 2559 non-null   object
#  7   host_listings_count                           2563 non-null   int64
#  8   host_total_listings_count                     2563 non-null   int64
# ...

# %%
type(new_listings_df['price'][0])
# Out:
# numpy.int64

# %%
new_listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2563 entries, 0 to 2562
# Data columns (total 33 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            2563 non-null   int64
#  1   name                                          2563 non-null   object
#  2   neighborhood_overview                         2001 non-null   object
#  3   host_id                                       2563 non-null   int64
#  4   host_name                                     2563 non-null   object
#  5   host_since                                    2563 non-null   object
#  6   host_location                                 2559 non-null   object
#  7   host_listings_count                           2563 non-null   int64
#  8   host_total_listings_count                     2563 non-null   int64
# ...

# %%
Number_of_hosts= len(new_listings_df.groupby('host_id'))
Number_of_hosts
# Out:
# 1642

# %%
max_listings=new_listings_df['host_listings_count'].max()
max_listings
# Out:
# 729

# %%
new_listings_df['host_id'].value_counts()
# Out:
# 167186184    104
# 96187307      41
# 149601167     38
# 151397468     23
# 134903005     20
#             ...
# 176828759      1
# 400858996      1
# 176072701      1
# 165107573      1
# 80696321       1
# Name: host_id, Length: 1642, dtype: int64

# %%
entries_for_max_host= new_listings_df.query('host_listings_count == @max_listings')

# %%
new_listings_df['host_location'].value_counts()
# Out:
# Asheville, North Carolina, United States    1769
# US                                           253
# Woodfin, North Carolina, United States        75
# Arden, North Carolina, United States          53
# United States                                 42
#                                             ...
# Nantucket, Massachusetts, United States        1
# Floyds Knobs, Indiana, United States           1
# Daniels, Maryland, United States               1
# Baltimore, Maryland, United States             1
# Concord, North Carolina, United States         1
# Name: host_location, Length: 147, dtype: int64

# %%
listings_for_max_host_in_current_loc = len(new_listings_df.query('host_id == 151397468'))

# %%
new_listings_df.query("host_listings_count == 'max_listings'")
# Out:
# Empty DataFrame
# Columns: [id, name, neighborhood_overview, host_id, host_name, host_since, host_location, host_listings_count, host_total_listings_count, neighbourhood, latitude, longitude, room_type, price, minimum_nights, availability_30, availability_365, number_of_reviews, number_of_reviews_ltm, number_of_reviews_l30d, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_location, review_scores_value, license, calculated_host_listings_count, calculated_host_listings_count_entire_homes, calculated_host_listings_count_private_rooms, calculated_host_listings_count_shared_rooms, reviews_per_month]
# Index: []
#
# [0 rows x 33 columns]

# %%
new_l

# %%
number_of_listings_per_host = new_listings_df['host_listings_count'].value_counts().sort_values(ascending=False)
print(number_of_listings_per_host)
number_of_listings_per_host.plot(kind='bar')
# Out:
# 1      832
# 0      535
# 2      365
# 3      151
# 4      120
# 110    105
# 5       55
# 6       50
# 8       45
# 171     41
# 188     38
# 7       34
# 729     23
# 9       22
# 10      20
# 111     20
# 18      18
# 14      18
# 15      15
# 21      12
# 16      12
# 13       6
# 127      6
# 22       6
# 11       5
# 244      5
# 574      1
# 25       1
# 505      1
# 28       1
# Name: host_listings_count, dtype: int64
# <AxesSubplot:>

# %%
max_host=
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dx/xjmpmc054qj5vlxv2c52xq1w0000gn/T/ipykernel_1580/3763507899.py in <module>
# ----> 1 max_host= Index[new_listings_df['host_listings_count'].value_counts().sort_values(ascending=False)[0]]
#
# NameError: name 'Index' is not defined

# %%
all_accounts_for_same_host_name= new_listings_df['host_name'].value_counts()
new_listings_df.query('all_accounts_for_same_host_name > 10')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda3/envs/dai_env/lib/python3.9/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     199             if self.has_resolvers:
# --> 200                 return self.resolvers[key]
#     201
#
# /Applications/anaconda3/envs/dai_env/lib/python3.9/collections/__init__.py in __getitem__(self, key)
#     940                 pass
# --> 941         return self.__missing__(key)            # support subclasses that define __missing__
#     942
#
# /Applications/anaconda3/envs/dai_env/lib/python3.9/collections/__init__.py in __missing__(self, key)
#     932     def __missing__(self, key):
# --> 933         raise KeyError(key)
#     934
#
# KeyError: 'all_accounts_for_same_host_name'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
prices = new_listings_df['price']

def get_qualitative_dist(df_column, ylabel, title, imagename):
    median = round(np.median(df_column),2)
    mean = round(np.mean(df_column),2)
    mode_1 = list(stats.mode(df_column))
    fin_mode = mode_1[0]
    min_int=df_column.min()
    max_int=df_column.max()
    #print([min_int, max_int, median,mean,mode])
    fig, ax = plt.subplots(figsize =(10, 8))
    sns.boxplot(y= df_column, 
            showmeans=True,
            hue = df['room_type'],
           meanprops={"marker":"o",
                       "markerfacecolor":"yellow", 
                       "markeredgecolor":"black",
                      "markersize":"14"},
           width = 0.5,
           palette="Blues")
    plt.title(title)
    plt.savefig(imagename + '.png')
    plt.ylabel(ylabel)
    plt.legend(labels=[f"Min Value = {min_int} ",f"Max Value = {max_int}", f"Mean Value = {mean}", f"Median Value = {median}"], title = 'Qualitative Distributions')
    plt.show()

# %%
get_qualitative_dist(prices,'Nightly Price', 'Qualitative Distribution of Prices', 'BoxPlot of Prices')

# %%
pd.set_option('display.max_rows', 500)
prices.value_counts()[:100]
prices.value_counts()
# Out:
# 125     41
# 99      33
# 150     30
# 75      27
# 100     27
# 135     26
# 110     25
# 85      24
# 95      24
# 200     23
# 120     23
# 90      22
# 164     22
# 92      21
# 250     21
# 129     20
# 89      20
# 93      20
# 60      20
# 80      19
# 115     19
# 175     19
# 220     18
# 185     18
# 281     18
# 70      18
# 91      18
# 111     17
# 136     17
# 160     17
# 96      17
# 105     17
# 131     16
# 153     15
# 65      15
# 132     15
# 82      15
# 109     15
# 101     15
# 72      14
# 94      14
# 97      14
# 114     14
# 381     14
# 130     14
# 118     14
# 168     14
# 71      13
# 124     13
# 155     13
# 140     13
# 300     13
# 116     12
# 170     12
# 79      12
# 55      12
# 117     12
# 88      12
# 86      12
# 179     12
# 159     12
# 151     12
# 76      12
# 102     11
# 149     11
# 156     11
# 275     11
# 180     11
# 106     11
# 147     11
# 145     11
# 219     10
# 103     10
# 161     10
# 141     10
# 165     10
# ...

# %%
price_values=prices.value_counts()[:20]
plt.figure(figsize=(30,5))
plt.bar(range(len(price_values)), price_values.values, align='center')
plt.xticks(range(len(price_values)), price_values.index.values, size='small')
plt.title('Top 20 Most Occuring Nightly Prices ')
plt.show()

def make_bar_chart_from_column_values(df_column, figsize=(30,5), title='Title'):
    top_values= df_column.value_counts()[:20]
    high_value= top_values[0]
    low_value=top_values[-1]
    plt.figure(figsize=figsize)
    plt.bar(range(len(top_values)), top_values.values, align='center')
    plt.xticks(range(len(top_values)), top_values.index.values, size='small')
    plt.legend(labels=[f"Min Value = {min_int} ",f"Max Value = {max_int}", f"Mean Value = {mean}", f"Median Value = {median}"], title = 'Qualitative Distributions')
    plt.legend(labels=[f" Highest Value = {high_value}", f"Lowest Value= {low_value}"])
    plt.title(title)
    plt.show()

# %%
make_bar_chart_from_column_values(new_listings_df['host_id'],figsize=(30,5), title='Hosts With The Most Listings')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda3/envs/dai_env/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /Applications/anaconda3/envs/dai_env/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /Applications/anaconda3/envs/dai_env/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.figure(figsize=(12,5))
plt.hist(prices, bins=100)
plt.xticks(np.arange(min_int, max_int, step=150))
plt.ylabel('Number of listings')
plt.xlabel('Price')
plt.title('Price Distribution For AirBnB Listings- Per Night')
plt.legend()

plt.savefig('Price distrubution.png')

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#function to build distribution histogram for user defined column-data
def build_distribution_histogram(column_data,color, figsize_list, bins_int, step_size, ylabel, xlabel,title,imagename):
  #ensure user-provided variables are correct data-type:
    min_int=column_data.min()
    max_int=column_data.max()
    bins_int=int(bins_int)
    step_size=int(step_size)
    ylabel=str(ylabel)
    xlabel=str(xlabel)
    title=str(title)
    imagename=str(imagename)
    
  #build histogram plot:
    plt.figure(figsize=(figsize_list[0],figsize_list[1]))
    plt.hist(column_data, bins=bins_int, color=str(color))
    plt.xticks(np.arange(min_int, max_int, step=step_size))
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.title(title)
    plt.legend([f'Min Value:{min_int}',f'Max Value:{max_int}'], loc='upper right')
    plt.savefig(imagename +'.png')
    plt.show()

# %%
build_distribution_histogram(prices,'green',[20,5],150,100,'Number of listings at price','Price','Distribution of Prices','prices_function_graph')

# %%
# Out:
# '2021-10-18'

# %%
listings_detailed_df

# %%
build_distribution_histogram(prices,'green',[20,5],150,100,'Number of listings at price','Price','Distribution of Prices','prices_function_graph')

# %%
listings_detailed_df.loc[listings_detailed_df['id'] == 52828490]
# Out:
#             id                            listing_url       scrape_id  \
# 2562  52828490  https://www.airbnb.com/rooms/52828490  20211018161933
#
#      last_scraped                                             name  \
# 2562   2021-10-18  Monthly - Downtown West Asheville with Hot Tub!
#
#                                             description neighborhood_overview  \
# 2562  Enjoy the main level of our well-loved, 100 ye...                   NaN
#
#                                             picture_url   host_id  \
# 2562  https://a0.muscache.com/pictures/miso/Hosting-...  80696321
#
#                                         host_url  ...  \
# 2562  https://www.airbnb.com/users/show/80696321  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 2562                         NaN                    NaN                 NaN
#
#      license instant_bookable calculated_host_listings_count  \
# ...

# %%
new_listings_df.loc[new_listings_df['price'] == 19]
# Out:
#             id                                        name  \
# 835   24697002  The Baying Hound Campground {Tent Site #2}
# 860   25138871  The Baying Hound Campground {Tent Site #1}
# 913   26634224  The Baying Hound Campground {Tent Site #4}
# 1718  42981397  The Baying Hound Campground {Hammock Site}
#
#      neighborhood_overview    host_id         host_name  host_since  \
# 835                    NaN  151279507  Bobby And Amanda  2017-09-19
# 860                    NaN  151279507  Bobby And Amanda  2017-09-19
# 913                    NaN  151279507  Bobby And Amanda  2017-09-19
# 1718                   NaN  151279507  Bobby And Amanda  2017-09-19
#
#                                  host_location  host_listings_count  \
# 835   Asheville, North Carolina, United States                   18
# 860   Asheville, North Carolina, United States                   18
# 913   Asheville, North Carolina, United States                   18
# ...

# %%
https://www.airbnb.com/rooms/new_listings_df.loc[new_listings_df['price'] == 19]
